# %% [markdown]
# ## Data Loading and Pre-processing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/data_trimmed_clean.zip" -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data_trimmed/Train/Shooting/Shooting042_x264_1030.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2680.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_1260.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2690.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2740.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4510.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11010.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_9020.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1860.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_4560.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_130.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting027_x264_140.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_980.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_180.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_3130.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_3390.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_940.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1740.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2930.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_0.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_5070.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_390.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_5060.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_390.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_20.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_430.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_1560.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_1570.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2940.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7810.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4420.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4430.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_1280.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_200.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting054_x264_560.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_640.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting038_x264_1040.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1190.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_2560.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_770.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_540.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting044_x264_220.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_540.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_5020.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3270.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2900.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2910.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_2250.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_1520.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_5050.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_830.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_830.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_3180.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_1550.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4850.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_10520.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_8510.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_2300.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_1630.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_4400.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1900.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_1380.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_9140.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting023_x264_160.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11170.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2620.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4470.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_280.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_1300.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_1150.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_6320.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_3600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_1010.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_1000.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7390.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6930.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_140.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_180.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_940.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3690.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_30.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1230.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_0.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12690.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting027_x264_430.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_3440.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_3810.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting053_x264_560.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12860.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_560.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_200.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_2010.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_330.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_810.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_770.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3860.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_810.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4150.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4140.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_4090.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_8060.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1280.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_1340.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_1020.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_10050.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_5520.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_1050.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_2720.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3700.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_5550.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3820.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3830.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_3370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_600.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_1420.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4100.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2350.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2280.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2290.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11400.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_9430.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting023_x264_410.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_4170.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_10.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_520.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_250.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_20.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_4600.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_1180.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_9340.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting023_x264_360.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4670.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2420.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_1100.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_1350.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_6120.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_3400.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_170.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_740.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3070.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_740.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_5220.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_820.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_2050.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4880.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_1720.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_5250.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_3380.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting036_x264_2920.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_1750.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_10720.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_2100.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_8710.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_1430.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1840.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_930.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_1990.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_1980.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4620.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4630.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_1080.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_800.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_440.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_1240.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1390.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_2760.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_210.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_570.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting053_x264_210.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting027_x264_340.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_380.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_3330.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_3190.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1540.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_2150.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_2990.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_190.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_190.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_630.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_1760.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_1770.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_4910.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_3170.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_400.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_20.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2150.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4300.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2080.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2090.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting036_x264_3800.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_9630.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_4370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_720.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_8260.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1080.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_1140.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1840.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_1220.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_10250.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_1250.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_2520.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_230.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_5750.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3500.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_230.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting053_x264_760.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting051_x264_800.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_760.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_2210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_130.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting001_x264_210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_570.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting054_x264_210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_5830.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4350.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4340.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_4290.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_1210.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_1200.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_1940.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7190.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_340.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting003_x264_380.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3490.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting025_x264_1810.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1030.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12490.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_950.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting027_x264_630.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_990.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_3640.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_640.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_4210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_9750.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11760.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_490.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_2030.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4260.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_560.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_3010.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_350.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting044_x264_430.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_350.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_5630.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_50.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3460.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_2440.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting051_x264_1190.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting053_x264_40.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_1330.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting036_x264_3790.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11990.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_10330.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_1340.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1920.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_1020.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_8300.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4220.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_1490.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4230.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_410.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting054_x264_370.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_5950.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting054_x264_70.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_2370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1780.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_160.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_600.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting051_x264_960.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting053_x264_600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_3720.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting051_x264_790.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_3580.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_830.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1150.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1970.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_580.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_220.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_580.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_1820.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_1360.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_1370.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_3560.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_6040.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_1230.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_1060.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2480.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2490.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4710.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2540.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting023_x264_200.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_9220.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_8880.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_4760.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_330.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_4990.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting023_x264_40.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_1550.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1490.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_2060.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_8670.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_10640.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_1630.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_2840.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_5190.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_5330.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_1640.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_2130.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_940.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_3110.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_620.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_5340.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting044_x264_140.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_620.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting053_x264_370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_370.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_410.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_2600.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting038_x264_520.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_960.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting054_x264_600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_160.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_4680.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4750.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4740.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_850.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_1920.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_30.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_4870.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7580.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_1610.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_1600.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_750.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3080.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_790.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1420.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_2030.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12080.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_3250.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting027_x264_220.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1320.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_1180.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_3550.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_5480.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_1350.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_2680.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_950.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_190.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3760.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3770.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_190.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3990.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3980.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3850.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_2870.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2330.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_70.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2320.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_650.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_9590.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4270.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_480.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1510.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_2100.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_110.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1060.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7230.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6890.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting042_x264_740.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_740.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_5560.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_820.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3730.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1390.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12730.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_3740.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting027_x264_590.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_550.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_400.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_360.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_2070.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1540.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_290.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2310.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting001_x264_90.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6660.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_610.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_1650.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2360.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_4130.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_1410.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting044_x264_380.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_5180.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3200.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2970.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_1480.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_990.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_990.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting036_x264_3020.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_10480.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1650.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_1790.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4700.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting036_x264_2470.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1060.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_1960.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_1220.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_760.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_760.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2780.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2640.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_320.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2650.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_6280.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_570.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_820.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_3090.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12240.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_3230.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2890.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_910.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_230.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_550.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3240.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_5010.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_230.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_590.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_460.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7740.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1510.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_1160.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4590.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_1320.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4580.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_4440.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2610.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_80.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_10.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting036_x264_360.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6310.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2660.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1810.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1030.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_610.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting025_x264_170.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1730.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4890.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_1590.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_3140.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_5230.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_5090.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_2290.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2810.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3360.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_580.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_580.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_410.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_1190.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_240.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2730.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2720.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_600.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_9180.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_1340.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_1800.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting036_x264_2510.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1100.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4660.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2980.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7620.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1470.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_500.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_60.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_350.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3320.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_5170.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_350.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_430.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_870.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1780.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_3350.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_980.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12320.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting051_x264_140.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting027_x264_180.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_940.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_770.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1150.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_1080.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1970.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2700.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_680.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6270.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_200.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_4520.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2770.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_1240.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_1000.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3610.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_5590.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_830.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting051_x264_1230.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_1090.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_3430.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_10090.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_1380.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1240.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1470.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_2060.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4310.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_370.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2240.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_730.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting020_x264_2250.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2390.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_2910.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3930.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_160.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_430.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_3480.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_3620.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12650.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_5400.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3650.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting003_x264_140.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_620.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_980.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_180.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_620.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1100.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7350.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_1570.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2200.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_4050.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4190.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4180.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_1730.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_770.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6700.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2270.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1420.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_2110.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_560.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_200.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_420.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_3490.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12640.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_3630.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_630.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting003_x264_150.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_990.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3640.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_5410.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_630.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_190.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7340.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1110.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_1560.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4180.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4190.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_1720.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_4040.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2210.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_760.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6710.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2260.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_2100.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1430.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_570.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_5580.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_820.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3600.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3610.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting051_x264_1220.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_1080.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_3420.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_10080.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1250.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_1390.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4300.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1460.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_2070.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_360.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_360.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2380.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_2900.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_720.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2250.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2240.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_170.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3920.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2990.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_70.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1460.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7630.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_510.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting042_x264_340.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_420.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_340.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_5160.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3330.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1790.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_860.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12330.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_3340.png
# ...
#  extracting: /content/data_trimmed/Train/Shooting/Shooting054_x264_650.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_130.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6180.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_0.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_1970.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_800.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2480.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_4710.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_4700.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_3280.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3800.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_2820.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_20.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2360.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_240.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_240.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4220.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1540.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting036_x264_2150.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_4080.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_8190.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1370.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_3500.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting051_x264_1300.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_900.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3720.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3730.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_490.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_450.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_330.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12990.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting053_x264_490.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2340.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_2020.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1510.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_680.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3990.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_640.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6630.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_1440.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_1600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2330.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_4160.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1030.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7260.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_140.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_710.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_5530.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3760.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_710.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_500.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12760.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_3710.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_1930.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_1270.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4750.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_2420.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1030.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11080.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_730.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_730.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4580.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2600.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2610.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_520.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_280.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3380.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3250.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3240.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2920.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_5300.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting036_x264_3070.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting042_x264_50.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_1370.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_4410.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2640.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_1130.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6340.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_40.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting054_x264_490.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_330.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1060.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_2490.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_1080.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1840.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2630.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting031_x264_640.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting025_x264_120.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_680.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_3260.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_870.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_940.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_260.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_260.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_500.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3210.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_5040.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_1490.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_1480.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7710.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1540.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_430.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_3690.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_440.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2770.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2760.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_650.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_650.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_2540.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1150.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4630.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1990.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_1310.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_1850.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_4490.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1760.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_2390.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_8580.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_3110.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_5260.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_2840.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2980.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2990.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3320.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3330.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_720.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_2750.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_1920.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1100.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_250.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting040_x264_290.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6220.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_1050.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7880.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_4570.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2720.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting012_x264_1210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting029_x264_550.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7670.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1420.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_30.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3370.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_5120.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_300.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_460.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_300.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting038_x264_820.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_110.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_910.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_3300.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12370.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting052_x264_80.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting003_x264_1420.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_2030.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_4340.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_320.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_11490.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting041_x264_320.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_2200.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_2210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting039_x264_760.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting050_x264_2940.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_4190.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_690.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_3960.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_130.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_3650.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_3640.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting030_x264_860.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_3790.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting051_x264_1260.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_3460.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_1210.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_2250.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting014_x264_4000.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_1760.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting050_x264_1520.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_6750.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_880.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting036_x264_720.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_880.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting005_x264_2080.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting025_x264_1470.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_2220.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting025_x264_530.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_3880.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting031_x264_250.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting012_x264_290.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting052_x264_3670.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_12600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting051_x264_460.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting042_x264_670.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_5450.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_3600.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting003_x264_110.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting017_x264_670.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting014_x264_1150.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting006_x264_7300.png
#  extracting: /content/data_trimmed/Train/Shooting/Shooting020_x264_1090.png
#   inflating: /content/data_trimmed/Train/Shooting/Shooting009_x264_1080.png

# %%
# ONLY USED FOR TESTING AND DEBUGGING - for final model we will use the whole dataset

import os
import shutil

def create_debug_subset_sequential(source_dir, dest_dir, train_limit=10000, test_limit=4000):
    if os.path.exists(dest_dir):
        shutil.rmtree(dest_dir)
    os.makedirs(dest_dir, exist_ok=True)

    for split, limit in [("Train", train_limit), ("Test", test_limit)]:
        src_split_path = os.path.join(source_dir, split)
        dst_split_path = os.path.join(dest_dir, split)
        os.makedirs(dst_split_path, exist_ok=True)

        for class_name in os.listdir(src_split_path):
            class_src = os.path.join(src_split_path, class_name)
            class_dst = os.path.join(dst_split_path, class_name)
            os.makedirs(class_dst, exist_ok=True)

            valid_images = sorted([f for f in os.listdir(class_src) if f.endswith(".png") and not f.startswith("._")])
            selected_images = valid_images[:limit]

            for img in selected_images:
                shutil.copy(os.path.join(class_src, img), os.path.join(class_dst, img))

create_debug_subset_sequential("/content/data_trimmed", "/content/data_trimmed_debug", train_limit=10000, test_limit=4000)

# paths
train_dir = "/content/data_trimmed_debug/Train"
test_dir = "/content/data_trimmed_debug/Test"

# %%
import os
import shutil
from collections import defaultdict

def extract_video_id(filename):
    """
    Extracts the video ID by removing the frame suffix (assumes last underscore + digits is the frame number).
    For example:
        Normal_Videos_003_x264_0.png → Normal_Videos_003_x264
        Assault_001_frame_010.png → Assault_001
    """
    parts = filename.rsplit("_", 1)
    return parts[0] if len(parts) == 2 else filename.split("_frame")[0]

def restructure_dataset(src_dir, dst_dir):
    os.makedirs(dst_dir, exist_ok=True)

    for class_name in os.listdir(src_dir):
        class_path = os.path.join(src_dir, class_name)
        if not os.path.isdir(class_path):
            continue

        print(f"Processing class: {class_name}")
        video_frame_dict = defaultdict(list)

        for fname in os.listdir(class_path):
            if not fname.endswith('.png'):
                continue

            video_id = extract_video_id(fname)
            video_frame_dict[video_id].append(fname)

        for video_id, frames in video_frame_dict.items():
            video_folder_path = os.path.join(dst_dir, class_name, video_id)
            os.makedirs(video_folder_path, exist_ok=True)

            for frame in frames:
                src = os.path.join(class_path, frame)
                dst = os.path.join(video_folder_path, frame)
                shutil.copy2(src, dst)

    print(f"Done restructuring: {src_dir} → {dst_dir}\n")

# Paths
train_dir = "/content/data_trimmed/Train"
test_dir = "/content/data_trimmed/Test"

train_dst = "/content/data_trimmed_restructured/Train"
test_dst = "/content/data_trimmed_restructured/Test"

# Run restructuring
restructure_dataset(train_dir, train_dst)
restructure_dataset(test_dir, test_dst)
# Out:
# Processing class: Arson
# Processing class: Arrest
# Processing class: Shooting
# Processing class: Burglary
# Processing class: Explosion
# Processing class: NormalVideos
# Processing class: Assault
# Processing class: Fighting
# Done restructuring: /content/data_trimmed/Train → /content/data_trimmed_restructured/Train
#
# Processing class: Arson
# Processing class: Arrest
# Processing class: Shooting
# Processing class: Burglary
# Processing class: Explosion
# Processing class: NormalVideos
# Processing class: Assault
# Processing class: Fighting
# Done restructuring: /content/data_trimmed/Test → /content/data_trimmed_restructured/Test

# %%
IMG_HEIGHT = 64
IMG_WIDTH = 64
SEQUENCE_LENGTH = 16  # Pad/truncate each video to this many frames
BATCH_SIZE = 4
CLASS_NAMES = ['Arrest','Arson','Assault','Burglary','Explosion','Fighting','NormalVideos','Shooting']
NUM_CLASSES = len(CLASS_NAMES)

# %%
import tensorflow as tf
import numpy as np
import os
from glob import glob
from tensorflow.keras.utils import to_categorical
from PIL import Image

def load_video_frames(video_dir, sequence_length, img_size):
    # Get sorted list of frame paths
    frame_paths = sorted(glob(os.path.join(video_dir, "*.png")))

    frames = []
    for path in frame_paths[:sequence_length]:
        img = Image.open(path).resize(img_size)
        frame = np.array(img).astype("float32") / 255.0  # Normalize to [0, 1]
        frames.append(frame)

    # Pad with zeros if not enough frames
    while len(frames) < sequence_length:
        frames.append(np.zeros((img_size[1], img_size[0], 3), dtype="float32"))

    return np.stack(frames)

def get_video_paths_and_labels(base_dir, class_names):
    video_paths = []
    labels = []

    for class_index, class_name in enumerate(class_names):
        class_path = os.path.join(base_dir, class_name)
        for video_folder in os.listdir(class_path):
            video_path = os.path.join(class_path, video_folder)
            if os.path.isdir(video_path):
                video_paths.append(video_path)
                labels.append(class_index)

    return video_paths, labels

def build_video_dataset(base_dir, sequence_length, img_size, batch_size, class_names, shuffle=True):
    video_paths, labels = get_video_paths_and_labels(base_dir, class_names)

    def generator():
        for video_path, label in zip(video_paths, labels):
            frames = load_video_frames(video_path, sequence_length, img_size)
            yield frames, to_categorical(label, num_classes=len(class_names))

    dataset = tf.data.Dataset.from_generator(
        generator,
        output_signature=(
            tf.TensorSpec(shape=(sequence_length, img_size[1], img_size[0], 3), dtype=tf.float32),
            tf.TensorSpec(shape=(len(class_names),), dtype=tf.float32)
        )
    )

    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(video_paths))

    return dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
train_seq_dir = "/content/data_trimmed_restructured/Train"
test_seq_dir = "/content/data_trimmed_restructured/Test"

train_dataset = build_video_dataset(
    base_dir=train_seq_dir,
    sequence_length=SEQUENCE_LENGTH,
    img_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_names=CLASS_NAMES,
    shuffle=True
)

test_dataset = build_video_dataset(
    base_dir=test_seq_dir,
    sequence_length=SEQUENCE_LENGTH,
    img_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_names=CLASS_NAMES,
    shuffle=False
)

# %%
for x, y in train_dataset.take(1):
    print(x.shape)  # (8, 16, 64, 64, 3)
    print(y.shape)  # (8, 8)
# Out:
# (8, 16, 64, 64, 3)
# (8, 8)

# %% [markdown]
# ## CNN + LSTM with DenseNet121

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, TimeDistributed, GlobalAveragePooling2D, LSTM,
    Dropout, Dense
)
from tensorflow.keras.applications import DenseNet121

def build_cnn_lstm_model(sequence_length, img_height, img_width, num_classes):
    input_shape = (sequence_length, img_height, img_width, 3)
    inputs = Input(shape=input_shape)

    # 1. Feature extraction with DenseNet121 per frame
    base_cnn = DenseNet121(
        include_top=False,
        weights="imagenet",
        input_shape=(img_height, img_width, 3)
    )
    base_cnn.trainable = False  # freeze CNN

    x = TimeDistributed(base_cnn)(inputs)
    x = TimeDistributed(GlobalAveragePooling2D())(x)

    # 2. LSTM for temporal modeling
    x = LSTM(128, return_sequences=False)(x)
    x = Dropout(0.5)(x)

    # 3. Final classifier
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

model = build_cnn_lstm_model(
    sequence_length=SEQUENCE_LENGTH,
    img_height=IMG_HEIGHT,
    img_width=IMG_WIDTH,
    num_classes=NUM_CLASSES
)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
        tf.keras.metrics.AUC(name="auc")
    ]
)

model.summary()
# Out:
# Model: "functional_28"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_22 (InputLayer)     │ (None, 16, 64, 64, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_10             │ (None, 16, 2, 2, 1024) │     7,037,504 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_11             │ (None, 16, 1024)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,628,872 (29.10 MB)
#  Trainable params: 591,368 (2.26 MB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=8
)
# Out:
# Epoch 1/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 271s 6s/step - accuracy: 0.2417 - auc: 0.5376 - loss: 2.3326 - val_accuracy: 0.2500 - val_auc: 0.5935 - val_loss: 2.0526
# Epoch 2/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 288ms/step - accuracy: 0.3805 - auc: 0.7832 - loss: 1.7020 - val_accuracy: 0.2045 - val_auc: 0.6160 - val_loss: 2.0069
# Epoch 3/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.4149 - auc: 0.8383 - loss: 1.5346 - val_accuracy: 0.1591 - val_auc: 0.5892 - val_loss: 2.1610
# Epoch 4/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - accuracy: 0.5169 - auc: 0.8558 - loss: 1.4076 - val_accuracy: 0.2500 - val_auc: 0.6009 - val_loss: 2.0446
# Epoch 5/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 282ms/step - accuracy: 0.7567 - auc: 0.9660 - loss: 0.9979 - val_accuracy: 0.2727 - val_auc: 0.5963 - val_loss: 2.1172
# Epoch 6/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 287ms/step - accuracy: 0.8242 - auc: 0.9739 - loss: 0.8062 - val_accuracy: 0.1818 - val_auc: 0.5484 - val_loss: 2.2820
# Epoch 7/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.8285 - auc: 0.9725 - loss: 0.7929 - val_accuracy: 0.2273 - val_auc: 0.5890 - val_loss: 2.2645
# Epoch 8/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.8993 - auc: 0.9936 - loss: 0.5474 - val_accuracy: 0.2045 - val_auc: 0.5521 - val_loss: 2.3320

# %% [markdown]
# ## CNN + Transformer (DenseNet121 + Transformer Encoder)

# %%
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import (
    Input, TimeDistributed, GlobalAveragePooling2D,
    Dense, Dropout, LayerNormalization, Add, GlobalAveragePooling1D
)
from tensorflow.keras.models import Model

# Custom Transformer Encoder block
def transformer_encoder(inputs, head_size=64, num_heads=4, ff_dim=128, dropout=0.1):
    # Multi-head self-attention
    x = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=head_size)(inputs, inputs)
    x = tf.keras.layers.Dropout(dropout)(x)
    x = Add()([x, inputs])
    x = LayerNormalization()(x)

    # Feedforward
    x_ff = tf.keras.layers.Dense(ff_dim, activation='relu')(x)
    x_ff = tf.keras.layers.Dropout(dropout)(x_ff)
    x = Add()([x, x_ff])
    x = LayerNormalization()(x)

    return x

def build_cnn_transformer_model(sequence_length, img_height, img_width, num_classes):
    input_shape = (sequence_length, img_height, img_width, 3)
    inputs = Input(shape=input_shape)

    # Frame-level feature extraction
    base_cnn = DenseNet121(include_top=False, weights="imagenet", input_shape=(img_height, img_width, 3))
    base_cnn.trainable = False  # Freeze DenseNet
    x = TimeDistributed(base_cnn)(inputs)
    x = TimeDistributed(GlobalAveragePooling2D())(x)  # (batch, time, features)

    # Transformer encoder
    x = transformer_encoder(x, head_size=64, num_heads=4, ff_dim=1024, dropout=0.1)

    # Sequence pooling
    x = GlobalAveragePooling1D()(x)
    x = Dropout(0.4)(x)

    # Final classifier
    outputs = Dense(num_classes, activation='softmax')(x)

    return Model(inputs, outputs)

model = build_cnn_transformer_model(
    sequence_length=SEQUENCE_LENGTH,
    img_height=IMG_HEIGHT,
    img_width=IMG_WIDTH,
    num_classes=NUM_CLASSES
)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
        tf.keras.metrics.AUC(name="auc")
    ]
)

model.summary()
# Out:
# Model: "functional_29"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_24      │ (None, 16, 64,    │          0 │ -                 │
# │ (InputLayer)        │ 64, 3)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_12 │ (None, 16, 2, 2,  │  7,037,504 │ input_layer_24[0… │
# │ (TimeDistributed)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_13 │ (None, 16, 1024)  │          0 │ time_distributed… │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 16, 1024)  │  1,050,368 │ time_distributed… │
# │ (MultiHeadAttentio… │                   │            │ time_distributed… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 16, 1024)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 16, 1024)  │          0 │ dropout_30[0][0], │
# │                     │                   │            │ time_distributed… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 16, 1024)  │      2,048 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 16, 1024)  │  1,049,600 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 16, 1024)  │          0 │ dense_26[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 16, 1024)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 16, 1024)  │      2,048 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1024)      │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 1024)      │          0 │ global_average_p… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 8)         │      8,200 │ dropout_32[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,149,768 (34.90 MB)
#  Trainable params: 2,112,264 (8.06 MB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=8
)
# Out:
# Epoch 1/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 519s 18s/step - accuracy: 0.1202 - auc: 0.5042 - loss: 3.8438 - val_accuracy: 0.1818 - val_auc: 0.5947 - val_loss: 2.8060
# Epoch 2/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.5316 - auc: 0.8628 - loss: 1.4349 - val_accuracy: 0.1364 - val_auc: 0.6026 - val_loss: 3.0943
# Epoch 3/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.5468 - auc: 0.9175 - loss: 1.1435 - val_accuracy: 0.1364 - val_auc: 0.4816 - val_loss: 3.8098
# Epoch 4/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.8259 - auc: 0.9845 - loss: 0.4664 - val_accuracy: 0.0909 - val_auc: 0.5721 - val_loss: 3.6555
# Epoch 5/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.8257 - auc: 0.9869 - loss: 0.4322 - val_accuracy: 0.0909 - val_auc: 0.5174 - val_loss: 3.8544
# Epoch 6/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.8838 - auc: 0.9945 - loss: 0.2836 - val_accuracy: 0.2273 - val_auc: 0.5966 - val_loss: 4.0778
# Epoch 7/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9649 - auc: 0.9994 - loss: 0.1066 - val_accuracy: 0.1136 - val_auc: 0.5388 - val_loss: 4.7947
# Epoch 8/8
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.9787 - auc: 0.9999 - loss: 0.0499 - val_accuracy: 0.1364 - val_auc: 0.5736 - val_loss: 4.4803

# %% [markdown]
# ## DINOv2 + LSTM (using PyTorch)

# %%
## run just once on colab!
pip install transformers datasets timm

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image
from torchvision.transforms import Compose, Resize, ToTensor
from transformers import AutoImageProcessor, AutoModel
from PIL import Image
from glob import glob
from sklearn.preprocessing import LabelEncoder
import random

# Constants
SEQUENCE_LENGTH = 16
IMG_SIZE = 224
NUM_CLASSES = 8
BATCH_SIZE = 4
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
CLASS_NAMES = ['Arrest','Arson','Assault','Burglary','Explosion','Fighting','NormalVideos','Shooting']

# Label encoder
label_encoder = LabelEncoder()
label_encoder.fit(CLASS_NAMES)
# Out:
# LabelEncoder()

# %%
class VideoDataset(Dataset):
    def __init__(self, base_dir, sequence_length=16, image_size=224):
        self.sequence_length = sequence_length
        self.image_size = image_size
        self.samples = []
        self.processor = AutoImageProcessor.from_pretrained('facebook/dinov2-base')

        for class_name in os.listdir(base_dir):
            class_path = os.path.join(base_dir, class_name)
            if not os.path.isdir(class_path):
                continue
            for video_folder in os.listdir(class_path):
                video_path = os.path.join(class_path, video_folder)
                if os.path.isdir(video_path):
                    frame_paths = sorted(glob(os.path.join(video_path, '*.png')))
                    if len(frame_paths) > 0:
                        self.samples.append((frame_paths, label_encoder.transform([class_name])[0]))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        frame_paths, label = self.samples[idx]
        num_frames = len(frame_paths)

        # Sample or pad frames
        if num_frames >= self.sequence_length:
            selected = sorted(random.sample(frame_paths, self.sequence_length))
        else:
            selected = sorted(frame_paths)
            while len(selected) < self.sequence_length:
                selected.append(selected[-1])

        images = [Image.open(p).convert("RGB").resize((self.image_size, self.image_size)) for p in selected]
        processed = self.processor(images=images, return_tensors="pt")
        pixel_values = processed['pixel_values'].squeeze(0)  # shape: (T, 3, 224, 224)
        label = torch.tensor(label, dtype=torch.long)
        return pixel_values, label

# Paths
train_dir = "/content/data_trimmed_restructured/Train"
test_dir = "/content/data_trimmed_restructured/Test"

# Datasets & loaders
train_dataset = VideoDataset(train_dir, sequence_length=SEQUENCE_LENGTH, image_size=IMG_SIZE)
test_dataset = VideoDataset(test_dir, sequence_length=SEQUENCE_LENGTH, image_size=IMG_SIZE)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %%
class DINOv2_LSTM(nn.Module):
    def __init__(self, model_name='facebook/dinov2-base', hidden_dim=128, num_classes=NUM_CLASSES):
        super().__init__()
        self.vit = AutoModel.from_pretrained(model_name)
        self.vit.eval()
        for param in self.vit.parameters():
            param.requires_grad = False

        self.lstm = nn.LSTM(input_size=768, hidden_size=hidden_dim, batch_first=True)
        self.dropout = nn.Dropout(0.3)
        self.fc = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):  # x: (B, T, 3, 224, 224)
        B, T, C, H, W = x.shape
        x = x.view(B * T, C, H, W)

        with torch.no_grad():
            vit_out = self.vit(pixel_values=x).last_hidden_state[:, 0]  # CLS token

        x_seq = vit_out.view(B, T, -1)  # (B, T, 768)
        x_seq, _ = self.lstm(x_seq)
        x_seq = self.dropout(x_seq[:, -1, :])  # last time step
        return self.fc(x_seq)

# Model
model = DINOv2_LSTM().to(DEVICE)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.metrics import accuracy_score, roc_auc_score
import torch.nn.functional as F

def evaluate(model, loader, criterion, split='Test'):
    model.eval()
    total_loss = 0.0
    total_preds = []
    total_probs = []
    total_labels = []

    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            logits = model(x)
            probs = F.softmax(logits, dim=1)
            loss = criterion(logits, y)

            total_loss += loss.item()
            total_probs.append(probs.cpu())
            total_preds.append(torch.argmax(probs, dim=1).cpu())
            total_labels.append(y.cpu())

    y_true = torch.cat(total_labels).numpy()
    y_pred = torch.cat(total_preds).numpy()
    y_probs = torch.cat(total_probs).numpy()

    acc = accuracy_score(y_true, y_pred)

    try:
        auc = roc_auc_score(y_true, y_probs, multi_class='ovr', average='macro')
    except ValueError:
        auc = 0.0

    avg_loss = total_loss / len(loader)
    print(f"{split} Loss: {avg_loss:.4f} | Accuracy: {acc:.4f} | AUC: {auc:.4f}")


for epoch in range(8):
    model.train()
    running_loss = 0.0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    print(f"\nEpoch {epoch+1}, Train Loss: {avg_train_loss:.4f}")
    evaluate(model, train_loader, criterion, split='Train')
    evaluate(model, test_loader, criterion, split='Test')
# Out:
# Epoch 1, Train Loss: 2.0689
# Train Loss: 1.9803 | Accuracy: 0.2571 | AUC: 0.6444
# Test Loss: 2.0931 | Accuracy: 0.0909 | AUC: 0.4720
#
# Epoch 2, Train Loss: 1.9436
# Train Loss: 1.8665 | Accuracy: 0.4571 | AUC: 0.7944
# Test Loss: 2.0594 | Accuracy: 0.1591 | AUC: 0.5475
#
# Epoch 3, Train Loss: 1.8572
# Train Loss: 1.7593 | Accuracy: 0.5524 | AUC: 0.8828
# Test Loss: 2.0561 | Accuracy: 0.2273 | AUC: 0.5443
#
# Epoch 4, Train Loss: 1.7310
# Train Loss: 1.6553 | Accuracy: 0.6667 | AUC: 0.9441
# Test Loss: 2.0582 | Accuracy: 0.2273 | AUC: 0.5469
#
# Epoch 5, Train Loss: 1.6297
# Train Loss: 1.5382 | Accuracy: 0.7524 | AUC: 0.9676
# Test Loss: 2.0655 | Accuracy: 0.2273 | AUC: 0.5024
#
# Epoch 6, Train Loss: 1.5484
# Train Loss: 1.4716 | Accuracy: 0.7905 | AUC: 0.9791
# Test Loss: 2.0226 | Accuracy: 0.2500 | AUC: 0.5799
#
# Epoch 7, Train Loss: 1.4737
# Train Loss: 1.3904 | Accuracy: 0.8286 | AUC: 0.9875
# Test Loss: 2.0191 | Accuracy: 0.2500 | AUC: 0.5863
#
# Epoch 8, Train Loss: 1.3600
# Train Loss: 1.2838 | Accuracy: 0.9143 | AUC: 0.9928
# Test Loss: 2.0200 | Accuracy: 0.2500 | AUC: 0.5912

# %% [markdown]
# ## DINOv2 + Transformer Encoder (using PyTorch)

# %%
import torch
import torch.nn as nn
from transformers import AutoModel

class DINOv2_Transformer(nn.Module):
    def __init__(self, model_name='facebook/dinov2-base', hidden_dim=768, num_classes=8, num_heads=4, ff_dim=1024, dropout=0.1):
        super().__init__()

        # DINOv2 backbone
        self.vit = AutoModel.from_pretrained(model_name)
        self.vit.eval()
        for param in self.vit.parameters():
            param.requires_grad = False

        # Transformer Encoder block
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=hidden_dim,
            nhead=num_heads,
            dim_feedforward=ff_dim,
            dropout=dropout,
            batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=1)

        # Final classifier
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):  # x: (B, T, 3, 224, 224)
        B, T, C, H, W = x.shape
        x = x.view(B * T, C, H, W)

        with torch.no_grad():
            vit_out = self.vit(pixel_values=x).last_hidden_state[:, 0]  # CLS token

        x_seq = vit_out.view(B, T, -1)  # (B, T, 768)
        x_encoded = self.transformer_encoder(x_seq)  # (B, T, 768)
        x_pooled = x_encoded.mean(dim=1)  # average over time
        return self.fc(self.dropout(x_pooled))

model = DINOv2_Transformer().to(DEVICE)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
for epoch in range(20):
    model.train()
    running_loss = 0.0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    print(f"\nEpoch {epoch+1}, Train Loss: {avg_train_loss:.4f}")
    evaluate(model, train_loader, criterion, split='Train')
    evaluate(model, test_loader, criterion, split='Test')
# Out:
# Epoch 1, Train Loss: 2.0450
# Train Loss: 1.2645 | Accuracy: 0.6284 | AUC: 0.9366
# Test Loss: 1.8811 | Accuracy: 0.2941 | AUC: 0.6961
#
# Epoch 2, Train Loss: 1.2145
# Train Loss: 0.7473 | Accuracy: 0.8176 | AUC: 0.9917
# Test Loss: 1.7950 | Accuracy: 0.3725 | AUC: 0.7245
#
# Epoch 3, Train Loss: 0.7136
# Train Loss: 0.4388 | Accuracy: 0.9595 | AUC: 0.9994
# Test Loss: 1.8521 | Accuracy: 0.4118 | AUC: 0.7210
#
# Epoch 4, Train Loss: 0.4567
# Train Loss: 0.2259 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 1.8400 | Accuracy: 0.3922 | AUC: 0.7417
#
# Epoch 5, Train Loss: 0.2278
# Train Loss: 0.1187 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 1.9477 | Accuracy: 0.3725 | AUC: 0.7240
#
# Epoch 6, Train Loss: 0.1242
# Train Loss: 0.0764 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.0737 | Accuracy: 0.4118 | AUC: 0.7354
#
# Epoch 7, Train Loss: 0.0844
# Train Loss: 0.0583 | Accuracy: 0.9932 | AUC: 1.0000
# Test Loss: 2.0547 | Accuracy: 0.3725 | AUC: 0.7494
#
# Epoch 8, Train Loss: 0.0508
# Train Loss: 0.0325 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.1411 | Accuracy: 0.3922 | AUC: 0.7492
#
# Epoch 9, Train Loss: 0.0394
# Train Loss: 0.0236 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.2377 | Accuracy: 0.3725 | AUC: 0.7351
#
# Epoch 10, Train Loss: 0.0284
# Train Loss: 0.0172 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.2446 | Accuracy: 0.4118 | AUC: 0.7464
#
# Epoch 11, Train Loss: 0.0205
# Train Loss: 0.0172 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.2789 | Accuracy: 0.4118 | AUC: 0.7420
#
# Epoch 12, Train Loss: 0.0238
# Train Loss: 0.0120 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.4084 | Accuracy: 0.3725 | AUC: 0.7362
#
# Epoch 13, Train Loss: 0.0140
# Train Loss: 0.0096 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.4048 | Accuracy: 0.4118 | AUC: 0.7474
#
# Epoch 14, Train Loss: 0.0114
# Train Loss: 0.0077 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.5416 | Accuracy: 0.3725 | AUC: 0.7184
#
# Epoch 15, Train Loss: 0.0094
# Train Loss: 0.0064 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.5058 | Accuracy: 0.3922 | AUC: 0.7317
#
# Epoch 16, Train Loss: 0.0104
# Train Loss: 0.0068 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.4816 | Accuracy: 0.4118 | AUC: 0.7506
#
# Epoch 17, Train Loss: 0.0081
# Train Loss: 0.0054 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.3550 | Accuracy: 0.4118 | AUC: 0.7567
#
# Epoch 18, Train Loss: 0.0066
# Train Loss: 0.0063 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.5929 | Accuracy: 0.3333 | AUC: 0.7308
#
# Epoch 19, Train Loss: 0.0060
# Train Loss: 0.0042 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.5450 | Accuracy: 0.3529 | AUC: 0.7331
#
# Epoch 20, Train Loss: 0.0051
# Train Loss: 0.0038 | Accuracy: 1.0000 | AUC: 1.0000
# Test Loss: 2.5060 | Accuracy: 0.3725 | AUC: 0.7517

# %% [markdown]
# ## 3D CNN

# %%
class VideoDataset3D(VideoDataset):  # inherits from your existing DINO dataset
    def __getitem__(self, idx):
        pixel_values, label = super().__getitem__(idx)  # (T, 3, H, W)
        pixel_values = pixel_values.permute(1, 0, 2, 3)  # (3, T, H, W)
        return pixel_values, label

train_dataset = VideoDataset3D(train_dir, sequence_length=SEQUENCE_LENGTH, image_size=IMG_SIZE)
test_dataset = VideoDataset3D(test_dir, sequence_length=SEQUENCE_LENGTH, image_size=IMG_SIZE)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %%
class Simple3DCNN(nn.Module):
    def __init__(self, num_classes=8):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv3d(3, 32, kernel_size=(3, 5, 5), stride=1, padding=(1, 2, 2)),
            nn.BatchNorm3d(32),
            nn.ReLU(),
            nn.MaxPool3d((1, 2, 2)),

            nn.Conv3d(32, 64, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(),
            nn.MaxPool3d((2, 2, 2)),

            nn.Conv3d(64, 128, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(),
            nn.AdaptiveAvgPool3d((1, 1, 1)),  # output shape: (B, 128, 1, 1, 1)
        )
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):  # x: (B, 3, T, H, W)
        x = self.model(x)  # (B, 128, 1, 1, 1)
        x = x.view(x.size(0), -1)  # (B, 128)
        return self.fc(x)

model = Simple3DCNN(num_classes=NUM_CLASSES).to(DEVICE)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
for epoch in range(30):
    model.train()
    running_loss = 0.0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    print(f"\nEpoch {epoch+1}, Train Loss: {avg_train_loss:.4f}")
    evaluate(model, train_loader, criterion, split='Train')
    evaluate(model, test_loader, criterion, split='Test')
# Out:
# Epoch 1, Train Loss: 2.0921
# Train Loss: 2.0085 | Accuracy: 0.1892 | AUC: 0.6303
# Test Loss: 2.1123 | Accuracy: 0.2157 | AUC: 0.5528
#
# Epoch 2, Train Loss: 2.0162
# Train Loss: 1.9523 | Accuracy: 0.2500 | AUC: 0.6641
# Test Loss: 2.0611 | Accuracy: 0.1765 | AUC: 0.5854
#
# Epoch 3, Train Loss: 1.9936
# Train Loss: 1.9248 | Accuracy: 0.2635 | AUC: 0.6819
# Test Loss: 2.0474 | Accuracy: 0.1961 | AUC: 0.5825
#
# Epoch 4, Train Loss: 1.9649
# Train Loss: 1.9134 | Accuracy: 0.2770 | AUC: 0.6743
# Test Loss: 2.0175 | Accuracy: 0.1961 | AUC: 0.6129
#
# Epoch 5, Train Loss: 1.9463
# Train Loss: 1.8929 | Accuracy: 0.2973 | AUC: 0.6972
# Test Loss: 1.9990 | Accuracy: 0.2941 | AUC: 0.6445
#
# Epoch 6, Train Loss: 1.9338
# Train Loss: 1.8371 | Accuracy: 0.3446 | AUC: 0.7204
# Test Loss: 1.9375 | Accuracy: 0.2941 | AUC: 0.6634
#
# Epoch 7, Train Loss: 1.9094
# Train Loss: 1.8376 | Accuracy: 0.2500 | AUC: 0.7240
# Test Loss: 1.9472 | Accuracy: 0.3137 | AUC: 0.6661
#
# Epoch 8, Train Loss: 1.8591
# Train Loss: 1.8020 | Accuracy: 0.3716 | AUC: 0.7639
# Test Loss: 1.9176 | Accuracy: 0.3529 | AUC: 0.6556
#
# Epoch 9, Train Loss: 1.8875
# Train Loss: 1.7634 | Accuracy: 0.3378 | AUC: 0.7609
# Test Loss: 1.8968 | Accuracy: 0.3529 | AUC: 0.6905
#
# Epoch 10, Train Loss: 1.8786
# Train Loss: 1.7728 | Accuracy: 0.3716 | AUC: 0.7606
# Test Loss: 1.9219 | Accuracy: 0.2941 | AUC: 0.6970
#
# Epoch 11, Train Loss: 1.8856
# Train Loss: 1.7654 | Accuracy: 0.3446 | AUC: 0.7726
# Test Loss: 1.9683 | Accuracy: 0.2549 | AUC: 0.6986
#
# Epoch 12, Train Loss: 1.8880
# Train Loss: 1.7775 | Accuracy: 0.3851 | AUC: 0.7646
# Test Loss: 1.9707 | Accuracy: 0.2745 | AUC: 0.6649
#
# Epoch 13, Train Loss: 1.8648
# Train Loss: 1.7476 | Accuracy: 0.3716 | AUC: 0.7713
# Test Loss: 1.9022 | Accuracy: 0.3137 | AUC: 0.7051
#
# Epoch 14, Train Loss: 1.8337
# Train Loss: 1.7476 | Accuracy: 0.3919 | AUC: 0.7742
# Test Loss: 1.9133 | Accuracy: 0.2941 | AUC: 0.6991
#
# Epoch 15, Train Loss: 1.8540
# Train Loss: 1.7304 | Accuracy: 0.4324 | AUC: 0.7761
# Test Loss: 1.9120 | Accuracy: 0.3137 | AUC: 0.7196
#
# Epoch 16, Train Loss: 1.8079
# Train Loss: 1.7317 | Accuracy: 0.4257 | AUC: 0.7888
# Test Loss: 1.9110 | Accuracy: 0.3137 | AUC: 0.7039
#
# Epoch 17, Train Loss: 1.8413
# Train Loss: 1.6820 | Accuracy: 0.4324 | AUC: 0.8099
# Test Loss: 1.9074 | Accuracy: 0.3137 | AUC: 0.6512
#
# Epoch 18, Train Loss: 1.8184
# Train Loss: 1.7271 | Accuracy: 0.3581 | AUC: 0.7849
# Test Loss: 1.9663 | Accuracy: 0.3137 | AUC: 0.6743
#
# Epoch 19, Train Loss: 1.8083
# Train Loss: 1.7220 | Accuracy: 0.3649 | AUC: 0.7871
# Test Loss: 1.9581 | Accuracy: 0.2353 | AUC: 0.6866
#
# Epoch 20, Train Loss: 1.8061
# Train Loss: 1.6974 | Accuracy: 0.4122 | AUC: 0.8016
# Test Loss: 1.9100 | Accuracy: 0.2941 | AUC: 0.7017
#
# Epoch 21, Train Loss: 1.8018
# Train Loss: 1.7024 | Accuracy: 0.4122 | AUC: 0.8061
# Test Loss: 1.9193 | Accuracy: 0.2941 | AUC: 0.6872
#
# Epoch 22, Train Loss: 1.7737
# Train Loss: 1.6901 | Accuracy: 0.3716 | AUC: 0.7945
# Test Loss: 1.9100 | Accuracy: 0.3529 | AUC: 0.7176
#
# Epoch 23, Train Loss: 1.8130
# Train Loss: 1.6626 | Accuracy: 0.3514 | AUC: 0.8176
# Test Loss: 1.9584 | Accuracy: 0.2745 | AUC: 0.7017
#
# Epoch 24, Train Loss: 1.7675
# Train Loss: 1.6691 | Accuracy: 0.4054 | AUC: 0.8122
# Test Loss: 1.9124 | Accuracy: 0.3725 | AUC: 0.7094
#
# Epoch 25, Train Loss: 1.7830
# Train Loss: 1.6565 | Accuracy: 0.4257 | AUC: 0.8201
# Test Loss: 1.9305 | Accuracy: 0.2941 | AUC: 0.7002
#
# Epoch 26, Train Loss: 1.7592
# Train Loss: 1.7023 | Accuracy: 0.3919 | AUC: 0.8039
# Test Loss: 1.9691 | Accuracy: 0.2549 | AUC: 0.6654
#
# Epoch 27, Train Loss: 1.7705
# Train Loss: 1.6507 | Accuracy: 0.4189 | AUC: 0.8111
# Test Loss: 1.8922 | Accuracy: 0.3529 | AUC: 0.7151
#
# Epoch 28, Train Loss: 1.7669
# Train Loss: 1.6243 | Accuracy: 0.4324 | AUC: 0.8311
# Test Loss: 1.8905 | Accuracy: 0.2941 | AUC: 0.7020
#
# Epoch 29, Train Loss: 1.7290
# Train Loss: 1.6378 | Accuracy: 0.3851 | AUC: 0.8249
# Test Loss: 1.8708 | Accuracy: 0.2941 | AUC: 0.7193
#
# Epoch 30, Train Loss: 1.7670
# Train Loss: 1.6358 | Accuracy: 0.4257 | AUC: 0.8279
# Test Loss: 1.8946 | Accuracy: 0.2941 | AUC: 0.7197

# %% [markdown]
# ### Fine-tuning 3D CNN

# %% [markdown]
# #### Dropout

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Simple3DCNN_WithDropout(nn.Module):
    def __init__(self, num_classes=8):
        super().__init__()
        self.model = nn.Sequential(
            # Conv Block 1
            nn.Conv3d(3, 32, kernel_size=(3, 5, 5), stride=1, padding=(1, 2, 2)),
            nn.BatchNorm3d(32),
            nn.ReLU(),
            nn.MaxPool3d((1, 2, 2)),

            # Conv Block 2
            nn.Conv3d(32, 64, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(),
            nn.MaxPool3d((2, 2, 2)),

            # new: regularization after 2nd block
            nn.Dropout3d(p=0.3),

            # Conv Block 3
            nn.Conv3d(64, 128, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(),

            nn.AdaptiveAvgPool3d((1, 1, 1))  # output shape: (B, 128, 1, 1, 1)
        )
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):  # x: (B, 3, T, H, W)
        x = self.model(x)
        x = x.view(x.size(0), -1)  # flatten
        return self.fc(x)

model = Simple3DCNN_WithDropout(num_classes=NUM_CLASSES).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
for epoch in range(10):
    model.train()
    running_loss = 0.0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    print(f"\nEpoch {epoch+1}, Train Loss: {avg_train_loss:.4f}")
    evaluate(model, train_loader, criterion, split='Train')
    evaluate(model, test_loader, criterion, split='Test')
# Out:
# Epoch 1, Train Loss: 2.1297
# Train Loss: 2.0473 | Accuracy: 0.1689 | AUC: 0.6150
# Test Loss: 2.1120 | Accuracy: 0.0588 | AUC: 0.5644
#
# Epoch 2, Train Loss: 2.0733
# Train Loss: 2.0244 | Accuracy: 0.1959 | AUC: 0.6507
# Test Loss: 2.1500 | Accuracy: 0.0784 | AUC: 0.5750
#
# Epoch 3, Train Loss: 2.0680
# Train Loss: 2.0091 | Accuracy: 0.2162 | AUC: 0.6503
# Test Loss: 2.1405 | Accuracy: 0.0784 | AUC: 0.5662
#
# Epoch 4, Train Loss: 2.0635
# Train Loss: 1.9728 | Accuracy: 0.1892 | AUC: 0.6891
# Test Loss: 2.0763 | Accuracy: 0.1176 | AUC: 0.6324
#
# Epoch 5, Train Loss: 2.0541
# Train Loss: 1.9662 | Accuracy: 0.2365 | AUC: 0.6912
# Test Loss: 2.0718 | Accuracy: 0.1373 | AUC: 0.6180
#
# Epoch 6, Train Loss: 1.9998
# Train Loss: 1.9587 | Accuracy: 0.2230 | AUC: 0.6852
# Test Loss: 2.0439 | Accuracy: 0.2157 | AUC: 0.6230
#
# Epoch 7, Train Loss: 2.0180
# Train Loss: 1.9215 | Accuracy: 0.2432 | AUC: 0.7106
# Test Loss: 2.0006 | Accuracy: 0.2941 | AUC: 0.6509
#
# Epoch 8, Train Loss: 1.9655
# Train Loss: 1.8997 | Accuracy: 0.2838 | AUC: 0.7136
# Test Loss: 1.9779 | Accuracy: 0.3137 | AUC: 0.6229
#
# Epoch 9, Train Loss: 2.0227
# Train Loss: 1.9206 | Accuracy: 0.2905 | AUC: 0.7046
# Test Loss: 2.0060 | Accuracy: 0.2549 | AUC: 0.6219
#
# Epoch 10, Train Loss: 1.9860
# Train Loss: 1.8823 | Accuracy: 0.2568 | AUC: 0.7129
# Test Loss: 1.9770 | Accuracy: 0.2941 | AUC: 0.6123

# %% [markdown]
# #### Intermediate FC Layer

# %%
class Simple3DCNN_WithFC(nn.Module):
    def __init__(self, num_classes=8):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv3d(3, 32, kernel_size=(3, 5, 5), stride=1, padding=(1, 2, 2)),
            nn.BatchNorm3d(32),
            nn.ReLU(),
            nn.MaxPool3d((1, 2, 2)),

            nn.Conv3d(32, 64, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(),
            nn.MaxPool3d((2, 2, 2)),

            nn.Conv3d(64, 128, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(),

            nn.AdaptiveAvgPool3d((1, 1, 1))  # (B, 128, 1, 1, 1)
        )

        self.fc = nn.Sequential(
            nn.Flatten(),              # (B, 128)
            nn.Linear(128, 128),       # new intermediate layer
            nn.ReLU(),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):  # x: (B, 3, T, H, W)
        x = self.model(x)
        return self.fc(x)

model = Simple3DCNN_WithFC(num_classes=NUM_CLASSES).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
for epoch in range(10):
    model.train()
    running_loss = 0.0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    print(f"\nEpoch {epoch+1}, Train Loss: {avg_train_loss:.4f}")
    evaluate(model, train_loader, criterion, split='Train')
    evaluate(model, test_loader, criterion, split='Test')
# Out:
# Epoch 1, Train Loss: 2.0845
# Train Loss: 2.0420 | Accuracy: 0.2635 | AUC: 0.6396
# Test Loss: 2.0551 | Accuracy: 0.2549 | AUC: 0.6204
#
# Epoch 2, Train Loss: 2.0511
# Train Loss: 2.0146 | Accuracy: 0.2297 | AUC: 0.6606
# Test Loss: 2.0581 | Accuracy: 0.0980 | AUC: 0.6130
#
# Epoch 3, Train Loss: 2.0349
# Train Loss: 1.9763 | Accuracy: 0.2838 | AUC: 0.6972
# Test Loss: 2.0191 | Accuracy: 0.2745 | AUC: 0.6185
#
# Epoch 4, Train Loss: 1.9963
# Train Loss: 1.9615 | Accuracy: 0.2703 | AUC: 0.7071
# Test Loss: 2.0051 | Accuracy: 0.3922 | AUC: 0.6297
#
# Epoch 5, Train Loss: 2.0010
# Train Loss: 1.9415 | Accuracy: 0.2838 | AUC: 0.6984
# Test Loss: 2.0208 | Accuracy: 0.2353 | AUC: 0.6346
#
# Epoch 6, Train Loss: 1.9863
# Train Loss: 1.9499 | Accuracy: 0.2838 | AUC: 0.7210
# Test Loss: 1.9974 | Accuracy: 0.2549 | AUC: 0.6578
#
# Epoch 7, Train Loss: 1.9874
# Train Loss: 1.9037 | Accuracy: 0.2770 | AUC: 0.7291
# Test Loss: 1.9976 | Accuracy: 0.2157 | AUC: 0.6596
#
# Epoch 8, Train Loss: 1.9738
# Train Loss: 1.8888 | Accuracy: 0.2973 | AUC: 0.7377
# Test Loss: 1.9508 | Accuracy: 0.3333 | AUC: 0.6712
#
# Epoch 9, Train Loss: 1.9485
# Train Loss: 1.8831 | Accuracy: 0.3378 | AUC: 0.7419
# Test Loss: 2.0031 | Accuracy: 0.2157 | AUC: 0.6522
#
# Epoch 10, Train Loss: 1.9534
# Train Loss: 1.8835 | Accuracy: 0.3108 | AUC: 0.7331
# Test Loss: 2.0418 | Accuracy: 0.2157 | AUC: 0.6212

# %% [markdown]
# #### Extra Conv Layer

# %%
import torch
import torch.nn as nn

class Simple3DCNN_WithExtraConv(nn.Module):
    def __init__(self, num_classes=8):
        super().__init__()
        self.model = nn.Sequential(
            # Conv Block 1
            nn.Conv3d(3, 32, kernel_size=(3, 5, 5), stride=1, padding=(1, 2, 2)),
            nn.BatchNorm3d(32),
            nn.ReLU(),
            nn.MaxPool3d((1, 2, 2)),

            # Conv Block 2
            nn.Conv3d(32, 64, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(),
            nn.MaxPool3d((2, 2, 2)),

            # Conv Block 3
            nn.Conv3d(64, 128, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(),
            nn.MaxPool3d((2, 2, 2)),

            # ✅ New: Conv Block 4 (extra depth)
            nn.Conv3d(128, 256, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(256),
            nn.ReLU(),

            nn.AdaptiveAvgPool3d((1, 1, 1))  # (B, 256, 1, 1, 1)
        )

        self.fc = nn.Linear(256, num_classes)

    def forward(self, x):  # x: (B, 3, T, H, W)
        x = self.model(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

model = Simple3DCNN_WithExtraConv(num_classes=NUM_CLASSES).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
for epoch in range(15):
    model.train()
    running_loss = 0.0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    print(f"\nEpoch {epoch+1}, Train Loss: {avg_train_loss:.4f}")
    evaluate(model, train_loader, criterion, split='Train')
    evaluate(model, test_loader, criterion, split='Test')
# Out:
# Epoch 1, Train Loss: 2.1025
# Train Loss: 2.0014 | Accuracy: 0.2432 | AUC: 0.6462
# Test Loss: 2.0373 | Accuracy: 0.2157 | AUC: 0.6169
#
# Epoch 2, Train Loss: 2.0046
# Train Loss: 1.8817 | Accuracy: 0.2770 | AUC: 0.7030
# Test Loss: 2.0540 | Accuracy: 0.0980 | AUC: 0.6889
#
# Epoch 3, Train Loss: 1.9444
# Train Loss: 1.9204 | Accuracy: 0.2973 | AUC: 0.7006
# Test Loss: 1.9557 | Accuracy: 0.1961 | AUC: 0.7063
#
# Epoch 4, Train Loss: 1.9170
# Train Loss: 1.8612 | Accuracy: 0.3243 | AUC: 0.7220
# Test Loss: 1.9433 | Accuracy: 0.3333 | AUC: 0.6944
#
# Epoch 5, Train Loss: 1.9198
# Train Loss: 1.7981 | Accuracy: 0.3581 | AUC: 0.7529
# Test Loss: 1.9202 | Accuracy: 0.3333 | AUC: 0.6417
#
# Epoch 6, Train Loss: 1.8450
# Train Loss: 1.8089 | Accuracy: 0.3649 | AUC: 0.7552
# Test Loss: 2.0331 | Accuracy: 0.2549 | AUC: 0.6784
#
# Epoch 7, Train Loss: 1.8574
# Train Loss: 1.7304 | Accuracy: 0.3716 | AUC: 0.7776
# Test Loss: 1.9657 | Accuracy: 0.2157 | AUC: 0.6966
#
# Epoch 8, Train Loss: 1.8238
# Train Loss: 1.6983 | Accuracy: 0.3851 | AUC: 0.7885
# Test Loss: 2.0230 | Accuracy: 0.1765 | AUC: 0.6719
#
# Epoch 9, Train Loss: 1.8183
# Train Loss: 1.7284 | Accuracy: 0.3851 | AUC: 0.7627
# Test Loss: 1.9909 | Accuracy: 0.2941 | AUC: 0.6727
#
# Epoch 10, Train Loss: 1.7911
# Train Loss: 1.6447 | Accuracy: 0.4257 | AUC: 0.8053
# Test Loss: 1.8648 | Accuracy: 0.3333 | AUC: 0.7014
#
# Epoch 11, Train Loss: 1.7606
# Train Loss: 1.6873 | Accuracy: 0.3514 | AUC: 0.8049
# Test Loss: 2.0101 | Accuracy: 0.1569 | AUC: 0.7131
#
# Epoch 12, Train Loss: 1.7676
# Train Loss: 1.5878 | Accuracy: 0.4392 | AUC: 0.8200
# Test Loss: 1.9826 | Accuracy: 0.2549 | AUC: 0.6872
#
# Epoch 13, Train Loss: 1.7268
# Train Loss: 1.6803 | Accuracy: 0.3581 | AUC: 0.8109
# Test Loss: 1.9332 | Accuracy: 0.2745 | AUC: 0.6655
#
# Epoch 14, Train Loss: 1.7390
# Train Loss: 1.5926 | Accuracy: 0.4595 | AUC: 0.8162
# Test Loss: 1.9193 | Accuracy: 0.3137 | AUC: 0.6981
#
# Epoch 15, Train Loss: 1.7191
# Train Loss: 1.6346 | Accuracy: 0.3919 | AUC: 0.8092
# Test Loss: 1.8748 | Accuracy: 0.3529 | AUC: 0.7241

# %% [markdown]
# #### AdamW, Weight Decay

# %%
model = Simple3DCNN_WithExtraConv(num_classes=NUM_CLASSES).to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)

for epoch in range(15):
    model.train()
    running_loss = 0.0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    print(f"\nEpoch {epoch+1}, Train Loss: {avg_train_loss:.4f}")
    evaluate(model, train_loader, criterion, split='Train')
    evaluate(model, test_loader, criterion, split='Test')
# Out:
# Epoch 1, Train Loss: 2.2042
# Train Loss: 1.9992 | Accuracy: 0.1959 | AUC: 0.6521
# Test Loss: 2.0778 | Accuracy: 0.1569 | AUC: 0.6246
#
# Epoch 2, Train Loss: 2.0503
# Train Loss: 2.0097 | Accuracy: 0.2162 | AUC: 0.6681
# Test Loss: 1.9412 | Accuracy: 0.3137 | AUC: 0.6066
#
# Epoch 3, Train Loss: 1.9644
# Train Loss: 1.8961 | Accuracy: 0.2568 | AUC: 0.7142
# Test Loss: 1.9336 | Accuracy: 0.2745 | AUC: 0.6490
#
# Epoch 4, Train Loss: 1.8907
# Train Loss: 2.0652 | Accuracy: 0.2770 | AUC: 0.6952
# Test Loss: 2.0670 | Accuracy: 0.1961 | AUC: 0.5886
#
# Epoch 5, Train Loss: 1.9330
# Train Loss: 1.8017 | Accuracy: 0.3176 | AUC: 0.7555
# Test Loss: 1.9442 | Accuracy: 0.3137 | AUC: 0.7106
#
# Epoch 6, Train Loss: 1.8565
# Train Loss: 1.7630 | Accuracy: 0.3581 | AUC: 0.7520
# Test Loss: 1.8509 | Accuracy: 0.3333 | AUC: 0.7109
#
# Epoch 7, Train Loss: 1.8571
# Train Loss: 1.7915 | Accuracy: 0.3446 | AUC: 0.7459
# Test Loss: 1.9860 | Accuracy: 0.3725 | AUC: 0.6443
#
# Epoch 8, Train Loss: 1.8499
# Train Loss: 1.7326 | Accuracy: 0.3919 | AUC: 0.7796
# Test Loss: 1.9343 | Accuracy: 0.2157 | AUC: 0.6711
#
# Epoch 9, Train Loss: 1.8300
# Train Loss: 1.7035 | Accuracy: 0.3716 | AUC: 0.7948
# Test Loss: 1.9051 | Accuracy: 0.2745 | AUC: 0.7110
#
# Epoch 10, Train Loss: 1.7871
# Train Loss: 1.7138 | Accuracy: 0.3986 | AUC: 0.7963
# Test Loss: 1.9496 | Accuracy: 0.2745 | AUC: 0.6722
#
# Epoch 11, Train Loss: 1.7452
# Train Loss: 1.7343 | Accuracy: 0.3716 | AUC: 0.7977
# Test Loss: 1.9529 | Accuracy: 0.2157 | AUC: 0.7199
#
# Epoch 12, Train Loss: 1.7971
# Train Loss: 1.6391 | Accuracy: 0.3851 | AUC: 0.8150
# Test Loss: 1.9261 | Accuracy: 0.2549 | AUC: 0.7045
#
# Epoch 13, Train Loss: 1.7682
# Train Loss: 1.6767 | Accuracy: 0.3446 | AUC: 0.7897
# Test Loss: 2.0144 | Accuracy: 0.2745 | AUC: 0.7021
#
# Epoch 14, Train Loss: 1.7178
# Train Loss: 1.5808 | Accuracy: 0.4595 | AUC: 0.8258
# Test Loss: 1.9379 | Accuracy: 0.2353 | AUC: 0.7122
#
# Epoch 15, Train Loss: 1.7005
# Train Loss: 1.7802 | Accuracy: 0.2973 | AUC: 0.7998
# Test Loss: 2.0637 | Accuracy: 0.2549 | AUC: 0.6722

# %% [markdown]
# #### Learning Rate Scheduler

# %%
from torch.optim.lr_scheduler import StepLR

model = Simple3DCNN_WithExtraConv(num_classes=NUM_CLASSES).to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)

for epoch in range(15):
    model.train()
    running_loss = 0.0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    print(f"\nEpoch {epoch+1}, Train Loss: {avg_train_loss:.4f}")
    evaluate(model, train_loader, criterion, split='Train')
    evaluate(model, test_loader, criterion, split='Test')

    scheduler.step()

    current_lr = scheduler.get_last_lr()[0]
    print(f"Learning Rate after epoch {epoch+1}: {current_lr:.6f}")
# Out:
# Epoch 1, Train Loss: 2.1294
# Train Loss: 1.9996 | Accuracy: 0.2297 | AUC: 0.6187
# Test Loss: 2.0189 | Accuracy: 0.1765 | AUC: 0.6412
# Learning Rate after epoch 1: 0.000100
#
# Epoch 2, Train Loss: 1.9739
# Train Loss: 1.9743 | Accuracy: 0.2297 | AUC: 0.6583
# Test Loss: 2.0738 | Accuracy: 0.2157 | AUC: 0.6108
# Learning Rate after epoch 2: 0.000100
#
# Epoch 3, Train Loss: 1.9361
# Train Loss: 1.8577 | Accuracy: 0.2568 | AUC: 0.7042
# Test Loss: 1.9835 | Accuracy: 0.2941 | AUC: 0.6570
# Learning Rate after epoch 3: 0.000100
#
# Epoch 4, Train Loss: 1.9387
# Train Loss: 1.8326 | Accuracy: 0.3176 | AUC: 0.7396
# Test Loss: 1.9605 | Accuracy: 0.2941 | AUC: 0.6185
# Learning Rate after epoch 4: 0.000100
#
# Epoch 5, Train Loss: 1.8840
# Train Loss: 1.7401 | Accuracy: 0.3919 | AUC: 0.7563
# Test Loss: 1.9692 | Accuracy: 0.2549 | AUC: 0.7092
# Learning Rate after epoch 5: 0.000100
#
# Epoch 6, Train Loss: 1.8841
# Train Loss: 1.7740 | Accuracy: 0.3581 | AUC: 0.7593
# Test Loss: 1.9601 | Accuracy: 0.2353 | AUC: 0.6706
# Learning Rate after epoch 6: 0.000100
#
# Epoch 7, Train Loss: 1.8377
# Train Loss: 1.6997 | Accuracy: 0.3716 | AUC: 0.7815
# Test Loss: 1.9236 | Accuracy: 0.2941 | AUC: 0.7203
# Learning Rate after epoch 7: 0.000100
#
# Epoch 8, Train Loss: 1.7793
# Train Loss: 1.6947 | Accuracy: 0.3581 | AUC: 0.7876
# Test Loss: 1.9621 | Accuracy: 0.2157 | AUC: 0.6948
# Learning Rate after epoch 8: 0.000100
#
# Epoch 9, Train Loss: 1.7924
# Train Loss: 1.6668 | Accuracy: 0.3851 | AUC: 0.7948
# Test Loss: 2.0004 | Accuracy: 0.1373 | AUC: 0.6773
# Learning Rate after epoch 9: 0.000100
#
# Epoch 10, Train Loss: 1.8318
# Train Loss: 1.6153 | Accuracy: 0.4392 | AUC: 0.8147
# Test Loss: 1.8639 | Accuracy: 0.3333 | AUC: 0.6965
# Learning Rate after epoch 10: 0.000050
#
# Epoch 11, Train Loss: 1.7572
# Train Loss: 1.6191 | Accuracy: 0.4324 | AUC: 0.8247
# Test Loss: 1.8873 | Accuracy: 0.3529 | AUC: 0.7147
# Learning Rate after epoch 11: 0.000050
#
# Epoch 12, Train Loss: 1.7561
# Train Loss: 1.5531 | Accuracy: 0.4797 | AUC: 0.8407
# Test Loss: 1.9047 | Accuracy: 0.2941 | AUC: 0.7011
# Learning Rate after epoch 12: 0.000050
#
# Epoch 13, Train Loss: 1.6895
# Train Loss: 1.5753 | Accuracy: 0.4527 | AUC: 0.8300
# Test Loss: 1.9087 | Accuracy: 0.3137 | AUC: 0.6821
# Learning Rate after epoch 13: 0.000050
#
# Epoch 14, Train Loss: 1.6975
# Train Loss: 1.5342 | Accuracy: 0.4932 | AUC: 0.8477
# Test Loss: 1.9387 | Accuracy: 0.3333 | AUC: 0.7002
# Learning Rate after epoch 14: 0.000050
#
# Epoch 15, Train Loss: 1.7577
# Train Loss: 1.5608 | Accuracy: 0.4595 | AUC: 0.8219
# Test Loss: 1.9360 | Accuracy: 0.3333 | AUC: 0.7202
# Learning Rate after epoch 15: 0.000050

# %% [markdown]
# ## Grid Search

# %%
from torch.optim.lr_scheduler import StepLR

class Simple3DCNN_Searchable(nn.Module):
    def __init__(self, num_classes=8, dropout=None):
        super().__init__()
        layers = [
            nn.Conv3d(3, 32, kernel_size=(3, 5, 5), stride=1, padding=(1, 2, 2)),
            nn.BatchNorm3d(32),
            nn.ReLU(),
            nn.MaxPool3d((1, 2, 2)),

            nn.Conv3d(32, 64, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(),
            nn.MaxPool3d((2, 2, 2)),

            nn.Conv3d(64, 128, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(),
            nn.MaxPool3d((2, 2, 2)),

            nn.Conv3d(128, 256, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(256),
            nn.ReLU()
        ]

        if dropout:
            layers.append(nn.Dropout3d(p=dropout))

        layers.append(nn.AdaptiveAvgPool3d((1, 1, 1)))  # (B, 256, 1, 1, 1)

        self.model = nn.Sequential(*layers)
        self.fc = nn.Linear(256, num_classes)

    def forward(self, x):  # (B, 3, T, H, W)
        x = self.model(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

def run_grid_search(dropouts, lrs, decays, num_epochs=15):
    results_log = []

    for d in dropouts:
        for lr in lrs:
            for wd in decays:
                print(f"\n🔍 Trying: Dropout={d}, LR={lr}, WD={wd}")

                model = Simple3DCNN_Searchable(num_classes=NUM_CLASSES, dropout=d).to(DEVICE)
                criterion = torch.nn.CrossEntropyLoss()
                optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=wd)
                scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

                epoch_logs = []
                best_test_acc = 0
                best_test_auc = 0

                for epoch in range(num_epochs):
                    model.train()
                    running_loss = 0.0
                    for x, y in train_loader:
                        x, y = x.to(DEVICE), y.to(DEVICE)
                        optimizer.zero_grad()
                        logits = model(x)
                        loss = criterion(logits, y)
                        loss.backward()
                        optimizer.step()
                        running_loss += loss.item()

                    avg_train_loss = running_loss / len(train_loader)
                    train_acc, train_auc = evaluate(model, train_loader, criterion, return_metrics=True, split='Train')
                    test_acc, test_auc = evaluate(model, test_loader, criterion, return_metrics=True, split='Test')
                    test_loss = sum(criterion(model(x.to(DEVICE)), y.to(DEVICE)).item() for x, y in test_loader) / len(test_loader)

                    scheduler.step()

                    epoch_logs.append({
                        'epoch': epoch + 1,
                        'train_loss': avg_train_loss,
                        'train_acc': train_acc,
                        'train_auc': train_auc,
                        'test_loss': test_loss,
                        'test_acc': test_acc,
                        'test_auc': test_auc
                    })

                    # Track best
                    best_test_acc = max(best_test_acc, test_acc)
                    best_test_auc = max(best_test_auc, test_auc)

                results_log.append({
                    'dropout': d,
                    'lr': lr,
                    'weight_decay': wd,
                    'best_test_acc': best_test_acc,
                    'best_test_auc': best_test_auc,
                    'epoch_logs': epoch_logs
                })

    return results_log

from sklearn.metrics import accuracy_score, roc_auc_score
import torch.nn.functional as F

def evaluate(model, loader, criterion, split='Test', return_metrics=False):
    model.eval()
    total_loss = 0.0
    total_preds = []
    total_probs = []
    total_labels = []

    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            logits = model(x)
            probs = F.softmax(logits, dim=1)
            loss = criterion(logits, y)

            total_loss += loss.item()
            total_probs.append(probs.cpu())
            total_preds.append(torch.argmax(probs, dim=1).cpu())

            # ✅ Handle both one-hot and class indices
            if y.ndim > 1:
                total_labels.append(torch.argmax(y, dim=1).cpu())  # one-hot
            else:
                total_labels.append(y.cpu())  # already indices

    y_true = torch.cat(total_labels).numpy()
    y_pred = torch.cat(total_preds).numpy()
    y_probs = torch.cat(total_probs).numpy()

    acc = accuracy_score(y_true, y_pred)

    try:
        auc = roc_auc_score(y_true, y_probs, multi_class='ovr', average='macro')
    except ValueError:
        auc = 0.0  # fallback if batch too small

    avg_loss = total_loss / len(loader)

    if return_metrics:
        return acc, auc
    else:
        print(f"{split} Loss: {avg_loss:.4f} | Accuracy: {acc:.4f} | AUC: {auc:.4f}")

# %%
dropouts = [None, 0.2, 0.3]
lrs = [1e-4, 5e-4]
decays = [0, 1e-4]

results_log = run_grid_search(dropouts, lrs, decays, num_epochs=15)
# Out:
# 🔍 Trying: Dropout=None, LR=0.0001, WD=0
#
# 🔍 Trying: Dropout=None, LR=0.0001, WD=0.0001
#
# 🔍 Trying: Dropout=None, LR=0.0005, WD=0
#
# 🔍 Trying: Dropout=None, LR=0.0005, WD=0.0001
#
# 🔍 Trying: Dropout=0.2, LR=0.0001, WD=0
#
# 🔍 Trying: Dropout=0.2, LR=0.0001, WD=0.0001
#
# 🔍 Trying: Dropout=0.2, LR=0.0005, WD=0
#
# 🔍 Trying: Dropout=0.2, LR=0.0005, WD=0.0001
#
# 🔍 Trying: Dropout=0.3, LR=0.0001, WD=0
#
# 🔍 Trying: Dropout=0.3, LR=0.0001, WD=0.0001
#
# 🔍 Trying: Dropout=0.3, LR=0.0005, WD=0
#
# 🔍 Trying: Dropout=0.3, LR=0.0005, WD=0.0001

# %%
import pandas as pd

def format_grid_results(results_log):
    full_records = []

    for entry in results_log:
        config = {
            'dropout': entry['dropout'],
            'lr': entry['lr'],
            'weight_decay': entry['weight_decay']
        }

        for epoch_log in entry['epoch_logs']:
            record = {
                **config,
                'epoch': epoch_log['epoch'],
                'train_loss': epoch_log['train_loss'],
                'train_acc': epoch_log['train_acc'],
                'train_auc': epoch_log['train_auc'],
                'test_loss': epoch_log['test_loss'],
                'test_acc': epoch_log['test_acc'],
                'test_auc': epoch_log['test_auc']
            }
            full_records.append(record)

    return pd.DataFrame(full_records)

df = format_grid_results(results_log)

# %%
df[df['epoch'] == 15].sort_values(by='test_auc', ascending=False)
# Out:
#      dropout      lr  weight_decay  epoch  train_loss  train_acc  train_auc  \
# 74       0.2  0.0001        0.0000     15    1.742045   0.459459   0.849585
# 89       0.2  0.0001        0.0001     15    1.678071   0.432432   0.826802
# 14       NaN  0.0001        0.0000     15    1.663085   0.439189   0.819060
# 104      0.2  0.0005        0.0000     15    1.842501   0.405405   0.786754
# 164      0.3  0.0005        0.0000     15    1.766595   0.425676   0.772534
# 29       NaN  0.0001        0.0001     15    1.694645   0.405405   0.830233
# 119      0.2  0.0005        0.0001     15    1.806051   0.337838   0.798177
# 179      0.3  0.0005        0.0001     15    1.881730   0.304054   0.752227
# 149      0.3  0.0001        0.0001     15    1.709424   0.506757   0.850742
# 44       NaN  0.0005        0.0000     15    1.778813   0.425676   0.806054
# 134      0.3  0.0001        0.0000     15    1.728179   0.432432   0.830672
# 59       NaN  0.0005        0.0001     15    1.838665   0.385135   0.810563
#
#      test_loss  test_acc  test_auc
# 74    1.830022  0.274510  0.738911
# 89    1.879143  0.352941  0.720647
# 14    2.014307  0.294118  0.701890
# 104   1.884348  0.392157  0.701118
# 164   1.905265  0.274510  0.696267
# 29    1.923454  0.274510  0.688177
# 119   1.986745  0.294118  0.680032
# 179   1.854679  0.352941  0.677972
# 149   1.947626  0.274510  0.676775
# 44    1.948719  0.274510  0.672286
# 134   1.881763  0.313725  0.664073
# 59    1.866959  0.313725  0.663579

# %% [markdown]
# ## Final 3d cnn model

# %%
class Simple3DCNN_Final(nn.Module):
    def __init__(self, num_classes=8, dropout=0.2):
        super().__init__()
        layers = [
            nn.Conv3d(3, 32, kernel_size=(3, 5, 5), stride=1, padding=(1, 2, 2)),
            nn.BatchNorm3d(32),
            nn.ReLU(),
            nn.MaxPool3d((1, 2, 2)),

            nn.Conv3d(32, 64, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(),
            nn.MaxPool3d((2, 2, 2)),

            nn.Conv3d(64, 128, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(),
            nn.MaxPool3d((2, 2, 2)),

            nn.Conv3d(128, 256, kernel_size=(3, 3, 3), stride=1, padding=1),
            nn.BatchNorm3d(256),
            nn.ReLU()
        ]

        if dropout:
            layers.append(nn.Dropout3d(p=dropout))

        layers.append(nn.AdaptiveAvgPool3d((1, 1, 1)))  # (B, 256, 1, 1, 1)

        self.model = nn.Sequential(*layers)
        self.fc = nn.Linear(256, num_classes)

    def forward(self, x):
        x = self.model(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

# %%
from torch.optim.lr_scheduler import StepLR
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, roc_auc_score

model = Simple3DCNN_Final(num_classes=NUM_CLASSES, dropout=0.2).to(DEVICE)

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=0.0)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

def evaluate(model, loader, criterion, split='Test', return_metrics=False):
    model.eval()
    total_loss = 0.0
    total_preds = []
    total_probs = []
    total_labels = []

    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            logits = model(x)
            probs = F.softmax(logits, dim=1)
            loss = criterion(logits, y)

            total_loss += loss.item()
            total_probs.append(probs.cpu())
            total_preds.append(torch.argmax(probs, dim=1).cpu())

            # Handle both one-hot and class indices
            if y.ndim > 1:
                total_labels.append(torch.argmax(y, dim=1).cpu())  # one-hot
            else:
                total_labels.append(y.cpu())  # already indices

    y_true = torch.cat(total_labels).numpy()
    y_pred = torch.cat(total_preds).numpy()
    y_probs = torch.cat(total_probs).numpy()

    acc = accuracy_score(y_true, y_pred)

    try:
        auc = roc_auc_score(y_true, y_probs, multi_class='ovr', average='macro')
    except ValueError:
        auc = 0.0  # fallback if batch too small

    avg_loss = total_loss / len(loader)

    if return_metrics:
        return acc, auc
    else:
        print(f"{split} Loss: {avg_loss:.4f} | Accuracy: {acc:.4f} | AUC: {auc:.4f}")

for epoch in range(30):
    model.train()
    running_loss = 0.0
    for x, y in train_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    print(f"\nEpoch {epoch+1}, Train Loss: {avg_train_loss:.4f}")
    evaluate(model, train_loader, criterion, split='Train')
    evaluate(model, test_loader, criterion, split='Test')

    scheduler.step()
    print(f"Learning Rate after epoch {epoch+1}: {scheduler.get_last_lr()[0]:.6f}")
# Out:
# Epoch 1, Train Loss: 2.0865
# Train Loss: 1.9377 | Accuracy: 0.2892 | AUC: 0.6775
# Test Loss: 2.1289 | Accuracy: 0.1846 | AUC: 0.5985
# Learning Rate after epoch 1: 0.000100
#
# Epoch 2, Train Loss: 1.9533
# Train Loss: 1.9497 | Accuracy: 0.3275 | AUC: 0.6551
# Test Loss: 2.1455 | Accuracy: 0.2154 | AUC: 0.6474
# Learning Rate after epoch 2: 0.000100
#
# Epoch 3, Train Loss: 1.8690
# Train Loss: 1.7998 | Accuracy: 0.3902 | AUC: 0.7284
# Test Loss: 1.9497 | Accuracy: 0.3538 | AUC: 0.6489
# Learning Rate after epoch 3: 0.000100
#
# Epoch 4, Train Loss: 1.8441
# Train Loss: 1.9236 | Accuracy: 0.3275 | AUC: 0.7193
# Test Loss: 2.1721 | Accuracy: 0.2923 | AUC: 0.6254
# Learning Rate after epoch 4: 0.000100
#
# Epoch 5, Train Loss: 1.8525
# Train Loss: 1.9359 | Accuracy: 0.2822 | AUC: 0.7089
# Test Loss: 2.0097 | Accuracy: 0.2615 | AUC: 0.6800
# Learning Rate after epoch 5: 0.000100
#
# Epoch 6, Train Loss: 1.8545
# Train Loss: 1.7951 | Accuracy: 0.3728 | AUC: 0.7474
# Test Loss: 1.9587 | Accuracy: 0.3077 | AUC: 0.6723
# Learning Rate after epoch 6: 0.000100
#
# Epoch 7, Train Loss: 1.8505
# Train Loss: 1.7696 | Accuracy: 0.3937 | AUC: 0.7686
# Test Loss: 1.8701 | Accuracy: 0.3231 | AUC: 0.6806
# Learning Rate after epoch 7: 0.000100
#
# Epoch 8, Train Loss: 1.8274
# Train Loss: 1.7295 | Accuracy: 0.4042 | AUC: 0.7782
# Test Loss: 1.9041 | Accuracy: 0.2769 | AUC: 0.6765
# Learning Rate after epoch 8: 0.000100
#
# Epoch 9, Train Loss: 1.7977
# Train Loss: 1.7091 | Accuracy: 0.4111 | AUC: 0.7871
# Test Loss: 1.9182 | Accuracy: 0.3538 | AUC: 0.6957
# Learning Rate after epoch 9: 0.000100
#
# Epoch 10, Train Loss: 1.8075
# Train Loss: 1.6539 | Accuracy: 0.4599 | AUC: 0.8009
# Test Loss: 1.9893 | Accuracy: 0.3077 | AUC: 0.6588
# Learning Rate after epoch 10: 0.000050
#
# Epoch 11, Train Loss: 1.7737
# Train Loss: 1.6718 | Accuracy: 0.4286 | AUC: 0.8041
# Test Loss: 1.9494 | Accuracy: 0.3077 | AUC: 0.6853
# Learning Rate after epoch 11: 0.000050
#
# Epoch 12, Train Loss: 1.7491
# Train Loss: 1.6815 | Accuracy: 0.4216 | AUC: 0.8094
# Test Loss: 1.9107 | Accuracy: 0.2923 | AUC: 0.6867
# Learning Rate after epoch 12: 0.000050
#
# Epoch 13, Train Loss: 1.7203
# Train Loss: 1.8158 | Accuracy: 0.3833 | AUC: 0.7902
# Test Loss: 2.1428 | Accuracy: 0.2923 | AUC: 0.6765
# Learning Rate after epoch 13: 0.000050
#
# Epoch 14, Train Loss: 1.7099
# Train Loss: 1.6155 | Accuracy: 0.4774 | AUC: 0.8234
# Test Loss: 1.8914 | Accuracy: 0.2923 | AUC: 0.6988
# Learning Rate after epoch 14: 0.000050
#
# Epoch 15, Train Loss: 1.7246
# Train Loss: 1.6428 | Accuracy: 0.4564 | AUC: 0.8059
# Test Loss: 1.9389 | Accuracy: 0.2923 | AUC: 0.6597
# Learning Rate after epoch 15: 0.000050
#
# Epoch 16, Train Loss: 1.6974
# Train Loss: 1.5724 | Accuracy: 0.5122 | AUC: 0.8365
# Test Loss: 1.8676 | Accuracy: 0.2615 | AUC: 0.6925
# Learning Rate after epoch 16: 0.000050
#
# Epoch 17, Train Loss: 1.7162
# Train Loss: 1.6405 | Accuracy: 0.4425 | AUC: 0.8226
# Test Loss: 2.0302 | Accuracy: 0.2923 | AUC: 0.6850
# Learning Rate after epoch 17: 0.000050
#
# Epoch 18, Train Loss: 1.7028
# Train Loss: 1.5661 | Accuracy: 0.4843 | AUC: 0.8426
# Test Loss: 1.8920 | Accuracy: 0.3231 | AUC: 0.7098
# Learning Rate after epoch 18: 0.000050
#
# Epoch 19, Train Loss: 1.6984
# Train Loss: 1.5881 | Accuracy: 0.5052 | AUC: 0.8362
# Test Loss: 1.8730 | Accuracy: 0.3077 | AUC: 0.7001
# Learning Rate after epoch 19: 0.000050
#
# Epoch 20, Train Loss: 1.7157
# Train Loss: 1.6057 | Accuracy: 0.4913 | AUC: 0.8385
# Test Loss: 1.9386 | Accuracy: 0.3692 | AUC: 0.7238
# Learning Rate after epoch 20: 0.000025
#
# Epoch 21, Train Loss: 1.7005
# Train Loss: 1.5335 | Accuracy: 0.5470 | AUC: 0.8503
# Test Loss: 1.8094 | Accuracy: 0.3385 | AUC: 0.7385
# Learning Rate after epoch 21: 0.000025
#
# Epoch 22, Train Loss: 1.6596
# Train Loss: 1.5483 | Accuracy: 0.5052 | AUC: 0.8423
# Test Loss: 1.8654 | Accuracy: 0.3231 | AUC: 0.7225
# Learning Rate after epoch 22: 0.000025
#
# Epoch 23, Train Loss: 1.6469
# Train Loss: 1.5460 | Accuracy: 0.4808 | AUC: 0.8476
# Test Loss: 1.8830 | Accuracy: 0.3231 | AUC: 0.7100
# Learning Rate after epoch 23: 0.000025
#
# Epoch 24, Train Loss: 1.6158
# Train Loss: 1.5034 | Accuracy: 0.5122 | AUC: 0.8632
# Test Loss: 1.8478 | Accuracy: 0.3231 | AUC: 0.7332
# Learning Rate after epoch 24: 0.000025
#
# Epoch 25, Train Loss: 1.6222
# Train Loss: 1.5309 | Accuracy: 0.5157 | AUC: 0.8472
# Test Loss: 1.9143 | Accuracy: 0.3385 | AUC: 0.7059
# Learning Rate after epoch 25: 0.000025
#
# Epoch 26, Train Loss: 1.6420
# Train Loss: 1.5003 | Accuracy: 0.5122 | AUC: 0.8620
# Test Loss: 1.8322 | Accuracy: 0.3538 | AUC: 0.7544
# Learning Rate after epoch 26: 0.000025
#
# Epoch 27, Train Loss: 1.6440
# Train Loss: 1.5079 | Accuracy: 0.5296 | AUC: 0.8549
# Test Loss: 1.8336 | Accuracy: 0.4000 | AUC: 0.7234
# Learning Rate after epoch 27: 0.000025
#
# Epoch 28, Train Loss: 1.6388
# Train Loss: 1.5227 | Accuracy: 0.5296 | AUC: 0.8538
# Test Loss: 1.8849 | Accuracy: 0.3231 | AUC: 0.7296
# Learning Rate after epoch 28: 0.000025
#
# Epoch 29, Train Loss: 1.6525
# Train Loss: 1.5064 | Accuracy: 0.5192 | AUC: 0.8628
# Test Loss: 1.8855 | Accuracy: 0.2769 | AUC: 0.7183
# Learning Rate after epoch 29: 0.000025
#
# Epoch 30, Train Loss: 1.5757
# Train Loss: 1.4764 | Accuracy: 0.5505 | AUC: 0.8702
# Test Loss: 1.8221 | Accuracy: 0.3385 | AUC: 0.7432
# Learning Rate after epoch 30: 0.000013
